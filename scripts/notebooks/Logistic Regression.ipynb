# %%
import pandas as pd
from cleanResultantMerge import getSummary

# %%
df = pd.read_csv('../data/clean_labeled_project_data.csv')

# %%
getSummary(df)
# Out:
# Rows,Columns (83350, 66)
#                                    nulls  distinct_count  \
# _projectid                             0           83350
# _teacher_acctid                        0           64224
# _schoolid                              0           29741
# school_ncesid                       5845           27269
# school_latitude                        0           28765
# school_longitude                       0           28772
# school_city                            0            5827
# school_state                           0              51
# school_zip                             0           11012
# school_metro                       10405               3
# school_district                      130            5805
# school_county                          3            1442
# school_charter                         0               2
# school_magnet                          0               2
# school_year_round                      0               2
# ...
